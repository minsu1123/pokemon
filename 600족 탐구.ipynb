# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import os

import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
df = pd.read_csv("C:/pokemon/pokemon_data.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
g = df[df['Total'] == 770]
g
# Out:
#        #                   Name  Type 1 Type 2  Total   HP  Attack  Defense  \
# 422  382    KyogrePrimal Kyogre   Water    NaN    770  100     150       90
# 424  383  GroudonPrimal Groudon  Ground   Fire    770  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary   600
# 422      180      160     90           3       True  True
# 424      150       90     90           3       True  True

# %%
gh= df[df['Total'] == 780]
gh
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384  RayquazaMega Rayquaza   Dragon    Flying    780  105     180
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary   600
# 163      100      154      100    130           1       True  True
# 164       70      194      120    140           1       True  True
# 426      100      180      100    115           3       True  True

# %%
a = df['Total']>= 600

# %%
a
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Total, Length: 800, dtype: bool

# %%
df['600'] = a

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
non_legendary = df[df['Legendary']==False]
non_legendary
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass  Poison    318  45      49       49
# 1      2                Ivysaur   Grass  Poison    405  60      62       63
# 2      3               Venusaur   Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4      4             Charmander    Fire     NaN    309  39      52       43
# ..   ...                    ...     ...     ...    ...  ..     ...      ...
# 787  711    GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 788  712               Bergmite     Ice     NaN    304  55      69       85
# 789  713                Avalugg     Ice     NaN    514  95     117      184
# 790  714                 Noibat  Flying  Dragon    245  40      30       35
# 791  715                Noivern  Flying  Dragon    535  85      70       80
#
# ...

# %%
six_hundred = non_legendary[non_legendary['600']==True]
six_hundred
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 141  130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 161  149                  Dragonite    Dragon    Flying    600   91     134
# 165  151                        Mew   Psychic       NaN    600  100     100
# 196  181      AmpharosMega Ampharos  Electric    Dragon    610   90      95
# ...

# %%
legendary = df[df['Legendary']==True]
legendary
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary    600
# ...

# %%
legendary_real = legendary

# %%
legendary_real['Total'] = legendary['Total']*9/10
legendary_real['HP'] = legendary['HP']*9/10
legendary_real['Defense']= legendary['Defense']*9/10
legendary_real['Sp. Atk']= legendary['Sp. Atk']*9/10
legendary_real['Sp. Def']= legendary['Sp. Def']*9/10
legendary_real['Speed']= legendary['Speed']*9/10

legendary_real
# Out:
# <ipython-input-123-6b381d38ab11>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   legendary_real['Total'] = legendary['Total']*9/10
# <ipython-input-123-6b381d38ab11>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   legendary_real['HP'] = legendary['HP']*9/10
# <ipython-input-123-6b381d38ab11>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
six_hundred_real = six_hundred

# %%
six_hundred_real['Total'] = six_hundred['Total']*9/10
six_hundred_real['HP'] = six_hundred['HP']*9/10
six_hundred_real['Attack']= six_hundred['Attack']*9/10
six_hundred_real['Defense']= six_hundred['Defense']*9/10
six_hundred_real['Sp. Atk']= six_hundred['Sp. Atk']*9/10
six_hundred_real['Sp. Def']= six_hundred['Sp. Def']*9/10
six_hundred_real['Speed']= six_hundred['Speed']*9/10

six_hundred_real
# Out:
# <ipython-input-127-7d49ec3566d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   six_hundred_real['Total'] = six_hundred['Total']*9/10
# <ipython-input-127-7d49ec3566d1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   six_hundred_real['HP'] = six_hundred['HP']*9/10
# <ipython-input-127-7d49ec3566d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## 자 이제 배틀에 적용 되는 실제 600족이랑 전설의 데이터를 얻었음

# %%
fig = legendary_real.iloc[:,0:12].hist(bins=20, color='blue', linewidth=1.0, xlabelsize=10, ylabelsize=10, xrot=45, yrot=0, figsize=(10,9), grid=False)
plt.tight_layout(rect=(0, 0, 1.5, 1.5))

# %%
fig = six_hundred_real.iloc[:,0:12].hist(bins=20, color='blue', linewidth=1.0, xlabelsize=10, ylabelsize=10, xrot=45, yrot=0, figsize=(10,9), grid=False)
plt.tight_layout(rect=(0, 0, 1.5, 1.5))

# %%
special_pokemon = non_legendary[non_legendary['600']==False]
special_pokemon
# Out:
#        #                 Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur   Grass  Poison    318  45      49       49
# 1      2              Ivysaur   Grass  Poison    405  60      62       63
# 2      3             Venusaur   Grass  Poison    525  80      82       83
# 4      4           Charmander    Fire     NaN    309  39      52       43
# 5      5           Charmeleon    Fire     NaN    405  58      64       58
# ..   ...                  ...     ...     ...    ...  ..     ...      ...
# 787  711  GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 788  712             Bergmite     Ice     NaN    304  55      69       85
# 789  713              Avalugg     Ice     NaN    514  95     117      184
# 790  714               Noibat  Flying  Dragon    245  40      30       35
# 791  715              Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary    600
# ...

# %%
s = special_pokemon[special_pokemon['Total']>=580]
s
# Out:
#        #                       Name   Type 1    Type 2  Total   HP  Attack  \
# 71    65      AlakazamMega Alakazam  Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro    Water   Psychic    590   95      75
# 124  115  KangaskhanMega Kangaskhan   Normal       NaN    590  105     125
# 366  334        AltariaMega Altaria   Dragon     Fairy    590   75     110
# 397  362          GlalieMega Glalie      Ice       NaN    580   80     120
# 476  428        LopunnyMega Lopunny   Normal  Fighting    580   65     136
# 511  460    AbomasnowMega Abomasnow    Grass       Ice    594   90     132
# 713  647       KeldeoOrdinary Forme    Water  Fighting    580   91      72
# 714  647       KeldeoResolute Forme    Water  Fighting    580   91      72
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary    600
# 71        65      175       95    150           1      False  False
# 87       180      130       80     30           1      False  False
# ...

# %%
fig = special_pokemon.iloc[:,0:12].hist(bins=20, color='blue', linewidth=1.0, xlabelsize=10, ylabelsize=10, xrot=45, yrot=0, figsize=(10,9), grid=False)
plt.tight_layout(rect=(0, 0, 1.5, 1.5))

# %%
l = legendary_real[legendary_real['Total'] >= 600]
l
# Out:
#        #                   Name   Type 1    Type 2  Total     HP  Attack  \
# 162  150                 Mewtwo  Psychic       NaN  612.0   95.4     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  702.0   95.4     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  702.0   95.4     150
# 269  249                  Lugia  Psychic    Flying  612.0   95.4      90
# 270  250                  Ho-oh     Fire    Flying  612.0   95.4     130
# 418  380      LatiasMega Latias   Dragon   Psychic  630.0   72.0     100
# 420  381      LatiosMega Latios   Dragon   Psychic  630.0   72.0     130
# 421  382                 Kyogre    Water       NaN  603.0   90.0     100
# 422  382    KyogrePrimal Kyogre    Water       NaN  693.0   90.0     150
# 423  383                Groudon   Ground       NaN  603.0   90.0     150
# 424  383  GroudonPrimal Groudon   Ground      Fire  693.0   90.0     180
# 425  384               Rayquaza   Dragon    Flying  612.0   94.5     150
# ...

# %%
u = legendary_real[legendary_real['Total'] >= 630]
t = u[u['Total']<=650]
t
# Out:
#        #                 Name  Type 1   Type 2  Total     HP  Attack  Defense  \
# 418  380    LatiasMega Latias  Dragon  Psychic  630.0   72.0     100    108.0
# 420  381    LatiosMega Latios  Dragon  Psychic  630.0   72.0     130     90.0
# 552  493               Arceus  Normal      NaN  648.0  108.0     120    108.0
# 711  646   KyuremBlack Kyurem  Dragon      Ice  630.0  112.5     170     90.0
# 712  646   KyuremWhite Kyurem  Dragon      Ice  630.0  112.5     120     81.0
# 796  719  DiancieMega Diancie    Rock    Fairy  630.0   45.0     160     99.0
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary   600
# 418    126.0    135.0   99.0           3       True  True
# 420    144.0    108.0   99.0           3       True  True
# 552    108.0    108.0  108.0           4       True  True
# 711    108.0     81.0   85.5           5       True  True
# 712    153.0     90.0   85.5           5       True  True
# 796    144.0     99.0   99.0           6       True  True

# %%
q = legendary_real[legendary_real['Total'] >= 600]
r = q[q['Total'] <630]
r
# Out:
#        #                   Name   Type 1    Type 2  Total     HP  Attack  \
# 162  150                 Mewtwo  Psychic       NaN  612.0   95.4     110
# 269  249                  Lugia  Psychic    Flying  612.0   95.4      90
# 270  250                  Ho-oh     Fire    Flying  612.0   95.4     130
# 421  382                 Kyogre    Water       NaN  603.0   90.0     100
# 423  383                Groudon   Ground       NaN  603.0   90.0     150
# 425  384               Rayquaza   Dragon    Flying  612.0   94.5     150
# 540  483                 Dialga    Steel    Dragon  612.0   90.0     120
# 541  484                 Palkia    Water    Dragon  612.0   81.0     120
# 543  486              Regigigas   Normal       NaN  603.0   99.0     160
# 544  487  GiratinaAltered Forme    Ghost    Dragon  612.0  135.0     100
# 545  487   GiratinaOrigin Forme    Ghost    Dragon  612.0  135.0     120
# 706  643               Reshiram   Dragon      Fire  612.0   90.0     120
# ...

# %%
v= six_hundred_real[six_hundred_real['Total'] >= 600]
v
# Out:
#        #                     Name  Type 1   Type 2  Total     HP  Attack  \
# 268  248  TyranitarMega Tyranitar    Rock     Dark  630.0   90.0   147.6
# 313  289                  Slaking  Normal      NaN  603.0  135.0   144.0
# 409  373  SalamenceMega Salamence  Dragon   Flying  630.0   85.5   130.5
# 413  376  MetagrossMega Metagross   Steel  Psychic  630.0   72.0   130.5
# 494  445    GarchompMega Garchomp  Dragon   Ground  630.0   97.2   153.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary   600
# 268    135.0     85.5    108.0   63.9           2      False  True
# 313     90.0     85.5     58.5   90.0           3      False  True
# 409    117.0    108.0     81.0  108.0           3      False  True
# 413    135.0     94.5     99.0   99.0           3      False  True
# 494    103.5    108.0     85.5   82.8           4      False  True
